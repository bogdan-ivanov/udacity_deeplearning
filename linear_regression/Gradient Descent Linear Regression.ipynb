# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


def error(x, y, m, b):
    return np.mean((m * x + b - y) ** 2)


def step_gradient(x, y, b, m, lr):
    m_gradient = np.mean(-x * (y - (m * x + b))) * 2
    b_gradient = np.mean(y - (m * x + b)) * 2
    return b - lr * b_gradient, m - lr * m_gradient


def gradient_descent(x, y, b, m, lr, iterations, print_step=10):
    errors = []
    plt.scatter(x, y)
    for iteration in xrange(iterations):
        b, m = step_gradient(x, y, b, m, lr)

        plt.plot(x, m * x + b, color=str(iteration / iterations))
        current_error = error(x, y, m, b)

        errors.append(current_error)
        if not iteration % print_step:
            print "Current Error at step=%s : %s" % (iteration, current_error)

    plt.show()

    plt.plot(range(iterations), errors)
    plt.show()

    return b, m



frame = pd.read_csv('data.csv')
print frame

LEARNING_RATE = 0.0001

INIT_B = 0.0
INIT_M = 0.0

MAX_ITERATIONS = 1000

points = frame.as_matrix()
x = points[:, 0]
y = points[:, 1]

b, m = gradient_descent(x, y, INIT_B, INIT_M, LEARNING_RATE, MAX_ITERATIONS)
print b, m
# Out:
#     32.502345269453031  31.70700584656992
# 0            53.426804          68.777596
# 1            61.530358          62.562382
# 2            47.475640          71.546632
# 3            59.813208          87.230925
# 4            55.142188          78.211518
# 5            52.211797          79.641973
# 6            39.299567          59.171489
# 7            48.105042          75.331242
# 8            52.550014          71.300880
# 9            45.419730          55.165677
# 10           54.351635          82.478847
# 11           44.164049          62.008923
# 12           58.168471          75.392870
# 13           56.727208          81.436192
# 14           48.955889          60.723602
# 15           44.687196          82.892504
# 16           60.297327          97.379897
# 17           45.618644          48.847153
# 18           38.816818          56.877213
# 19           66.189817          83.878565
# 20           65.416052         118.591217
# 21           47.481209          57.251819
# 22           41.575643          51.391744
# 23           51.845187          75.380652
# 24           59.370822          74.765564
# 25           57.310003          95.455053
# 26           63.615561          95.229366
# 27           46.737619          79.052406
# 28           50.556760          83.432071
# 29           52.223996          63.358790
# ..                 ...                ...
# 69           31.588117          50.392670
# 70           53.660932          63.642399
# 71           46.682229          72.247251
# 72           43.107820          57.812513
# 73           70.346076         104.257102
# 74           44.492856          86.642020
# 75           57.504533          91.486778
# 76           36.930077          55.231661
# 77           55.805733          79.550437
# 78           38.954769          44.847124
# 79           56.901215          80.207523
# 80           56.868901          83.142750
# 81           34.333125          55.723489
# 82           59.049741          77.634183
# 83           57.788224          99.051415
# 84           54.282329          79.120646
# 85           51.088720          69.588898
# 86           50.282836          69.510503
# 87           44.211742          73.687564
# 88           38.005488          61.366905
# 89           32.940480          67.170656
# 90           53.691640          85.668203
# 91           68.765734         114.853871
# 92           46.230966          90.123572
# 93           68.319361          97.919821
# 94           50.030174          81.536991
# 95           49.239765          72.111832
# 96           50.039576          85.232007
# 97           48.149859          66.224958
# 98           25.128485          53.454394
#
# [99 rows x 2 columns]
# Current Error at step=0 : 1481.18797684
# Current Error at step=10 : 111.107668555
# Current Error at step=20 : 111.106943693
# Current Error at step=30 : 111.107479394
# Current Error at step=40 : 111.108015174
# Current Error at step=50 : 111.108551033
# Current Error at step=60 : 111.109086972
# Current Error at step=70 : 111.109622989
# Current Error at step=80 : 111.110159085
# Current Error at step=90 : 111.11069526
# Current Error at step=100 : 111.111231515
# Current Error at step=110 : 111.111767848
# Current Error at step=120 : 111.11230426
# Current Error at step=130 : 111.112840751
# Current Error at step=140 : 111.113377321
# Current Error at step=150 : 111.113913971
# Current Error at step=160 : 111.114450699
# Current Error at step=170 : 111.114987506
# Current Error at step=180 : 111.115524393
# Current Error at step=190 : 111.116061359
# Current Error at step=200 : 111.116598403
# Current Error at step=210 : 111.117135527
# Current Error at step=220 : 111.11767273
# Current Error at step=230 : 111.118210012
# Current Error at step=240 : 111.118747373
# Current Error at step=250 : 111.119284813
# Current Error at step=260 : 111.119822333
# Current Error at step=270 : 111.120359932
# Current Error at step=280 : 111.12089761
# Current Error at step=290 : 111.121435367
# Current Error at step=300 : 111.121973203
# Current Error at step=310 : 111.122511119
# Current Error at step=320 : 111.123049113
# Current Error at step=330 : 111.123587187
# Current Error at step=340 : 111.124125341
# Current Error at step=350 : 111.124663573
# Current Error at step=360 : 111.125201885
# Current Error at step=370 : 111.125740276
# Current Error at step=380 : 111.126278747
# Current Error at step=390 : 111.126817297
# Current Error at step=400 : 111.127355926
# Current Error at step=410 : 111.127894634
# Current Error at step=420 : 111.128433422
# Current Error at step=430 : 111.12897229
# Current Error at step=440 : 111.129511236
# Current Error at step=450 : 111.130050262
# Current Error at step=460 : 111.130589368
# Current Error at step=470 : 111.131128552
# Current Error at step=480 : 111.131667817
# Current Error at step=490 : 111.13220716
# Current Error at step=500 : 111.132746583
# Current Error at step=510 : 111.133286086
# Current Error at step=520 : 111.133825668
# Current Error at step=530 : 111.13436533
# Current Error at step=540 : 111.134905071
# Current Error at step=550 : 111.135444891
# Current Error at step=560 : 111.135984791
# Current Error at step=570 : 111.136524771
# Current Error at step=580 : 111.13706483
# Current Error at step=590 : 111.137604969
# Current Error at step=600 : 111.138145187
# Current Error at step=610 : 111.138685485
# Current Error at step=620 : 111.139225863
# Current Error at step=630 : 111.13976632
# Current Error at step=640 : 111.140306856
# Current Error at step=650 : 111.140847473
# Current Error at step=660 : 111.141388169
# Current Error at step=670 : 111.141928944
# Current Error at step=680 : 111.1424698
# Current Error at step=690 : 111.143010735
# Current Error at step=700 : 111.143551749
# Current Error at step=710 : 111.144092844
# Current Error at step=720 : 111.144634018
# Current Error at step=730 : 111.145175271
# Current Error at step=740 : 111.145716605
# Current Error at step=750 : 111.146258018
# Current Error at step=760 : 111.146799511
# Current Error at step=770 : 111.147341084
# Current Error at step=780 : 111.147882737
# Current Error at step=790 : 111.148424469
# Current Error at step=800 : 111.148966281
# Current Error at step=810 : 111.149508173
# Current Error at step=820 : 111.150050145
# Current Error at step=830 : 111.150592196
# Current Error at step=840 : 111.151134328
# Current Error at step=850 : 111.151676539
# Current Error at step=860 : 111.15221883
# Current Error at step=870 : 111.152761202
# Current Error at step=880 : 111.153303653
# Current Error at step=890 : 111.153846184
# Current Error at step=900 : 111.154388794
# Current Error at step=910 : 111.154931485
# Current Error at step=920 : 111.155474256
# Current Error at step=930 : 111.156017106
# Current Error at step=940 : 111.156560037
# Current Error at step=950 : 111.157103048
# Current Error at step=960 : 111.157646138
# Current Error at step=970 : 111.158189309
# Current Error at step=980 : 111.15873256
# Current Error at step=990 : 111.15927589
# -0.102522977759 1.48364338395
